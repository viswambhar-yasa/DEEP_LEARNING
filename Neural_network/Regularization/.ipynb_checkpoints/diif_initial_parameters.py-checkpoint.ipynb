# %% [markdown]
# #### To understand optimize gradient descent, the initial parameter should be selected accordingly

# %%
## importing python libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets

# %%
## building a random training and testing dataset from sklearn library

# %%
np.random.seed(1)
train_X, train_Y = sklearn.datasets.make_circles(n_samples=300, noise=.08)
np.random.seed(2)
test_X, test_Y = sklearn.datasets.make_circles(n_samples=100, noise=.05)
# Visualize the data
plt.scatter(train_X[:, 0], train_X[:, 1], c=train_Y, s=40, cmap=plt.cm.Spectral)
plt.grid()
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Visualization of dataset')
train_X = train_X.T
train_Y = train_Y.reshape((1, train_Y.shape[0]))
test_X = test_X.T
test_Y = test_Y.reshape((1, test_Y.shape[0]))

# %%
## importing deep layered Neural network 
from NN_regularization import *

# %% [markdown]
# ### Running test cases to check if the NN is working or not

# %%
# !pytest test_NN_regular.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-5.3.5, py-1.8.1, pluggy-0.13.1
# rootdir: C:\Users\VISWAMBHAR YASA\ML\Deep_learning\DEEP_LEARNING\Neural_network\Regularization
# plugins: hypothesis-5.5.4, arraydiff-0.3, astropy-header-0.1.2, doctestplus-0.5.0, openfiles-0.4.0, remotedata-0.3.2
# collected 4 items
#
# test_NN_regular.py ....                                                  [100%]
#
# ============================== 4 passed in 0.03s ==============================

# %%
layer_dims=[3, 2, 1]

para,cost=NN_deep_layered(train_X,train_Y,layer_dims,num_iter=1000,learning_rate=0.05,p_ty='random',print_cost=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-d219515098df> in <module>
#       1 layer_dims=[3, 2, 1]
#       2
# ----> 3 para,cost=NN_deep_layered(train_X,train_Y,layer_dims,num_iter=1000,learning_rate=0.05,p_typ='random',print_cost=False)
#
# TypeError: NN_deep_layered() got an unexpected keyword argument 'p_typ'
