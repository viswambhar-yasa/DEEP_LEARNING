# %% [markdown]
# ### Neural Networks using dropout regularization
# DROPOUT : Randomly assigning zeros to neurons so they become inactive and thus reduce high variance

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
## importing dataset
file_pth='dataset/data.mat'
data = loadmat(file_pth)
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y', 'yval', 'Xval'])

# %%
train_X = data['X'].T
train_Y = data['y'].T
test_X = data['Xval'].T
test_Y = data['yval'].T

# %%
import matplotlib.colors as mcolors
plt.figure(figsize=(12,6))
ax = plt.axes()
# Setting the background color
ax.set_facecolor("green")
plt.scatter(train_X[0, :], train_X[1, :], c=train_Y, s=40,cmap=mcolors.ListedColormap(["red", "blue"]));
plt.legend(['player','opponent'])
plt.grid(axis='x',color = "white", linewidth = "0.5")
plt.title('Position of players on football field')
# Out:
# Text(0.5, 1.0, 'Position of players on football field')

# %% [markdown]
# ### UNDERSTANDING DATA SET
# ##### Data contains positions of player from last 10 games
# Each dot corresponds to a position on the football field where a football player has hit the ball with his/her head after the French goal keeper has shot the ball from the left side of the football field.
#
# ###### If the dot is yellow, it means the French player managed to hit the ball with his/her head
# ###### If the dot is purple, it means the other team's player hit the ball with their head.
# ## Goal: Use a deep learning model to find the positions on the field where the goalkeeper should kick the ball.

# %%
n=train_X.shape[0]
m=train_X.shape[1]
print('Number of Training examples m:',m)
print('Numnber of features n:',n)
# Out:
# Number of Training examples m: 211
# Numnber of features n: 2

# %%
n_test=test_X.shape[0]
m_test=test_X.shape[1]
print('Number of Training examples m:',m_test)
print('Numnber of features n:',n_test)
# Out:
# Number of Training examples m: 200
# Numnber of features n: 2

# %%
from NN_dropout_regularization import NN_deep_layered,predict,forward_propagation,predict

# %% [markdown]
# ### Running test cases to check if our NN is working or not

# %%
# !pytest test_NN_regular.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.4, pytest-5.4.2, py-1.8.1, pluggy-0.13.1
# rootdir: C:\Users\VISWAMBHAR YASA\ML\Deep_learning\DEEP_LEARNING\Neural_network\Regularization
# collected 3 items
#
# test_NN_regular.py ...                                                   [100%]
#
# ============================== 3 passed in 0.13s ==============================

# %%
layer_dims=[20, 3, 1]
para,cost=NN_deep_layered(train_X,train_Y,layer_dims,num_iter=30000,learning_rate=0.3,ke_prob=1,print_cost=False,p_ty='He')
print('TRAINING DATASET')
p_train=predict(train_X,train_Y,para)
print('TESTING DATASET')
p_train=predict(test_X,test_Y,para)
def pred(X, parameters, tol=0.5):
    m = X.shape[1]
    n_layers = len(parameters) // 2
    p = np.zeros((1, m))
    # Forward propagation
    probas, fw_caches = forward_propagation(X, parameters)
    # Activation function
    for i in range(0, probas.shape[1]):
        if probas[0, i] > tol:
            p[0, i] = 1
        else:
            p[0, i] = 0
    return p
X=train_X
Y=train_Y
x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
h = 0.01
# Generate a grid of points with distance h between them
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
# Predict the function value for the whole grid
Z = pred(np.c_[xx.ravel(), yy.ravel()].T,para)
Z = Z.reshape(xx.shape)
# Plot the contour and training examples
plt.figure(figsize=(12,6))
ax = plt.axes()
# Setting the background color
ax.set_facecolor("green")
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
plt.scatter(train_X[0, :], train_X[1, :], c=train_Y, s=40,cmap=mcolors.ListedColormap(["red", "blue"]));

plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.3)
plt.grid(axis='x',color = "white", linewidth = "0.5")
plt.title('Position of players on football field')
# Out:
# Number of Hidden layers in this Neural Network 3
# Units in each layer [20, 3, 1]
# TRAINING DATASET
# Hidden layer of the Neural Network 3
# Accuracy: 91.94312796208531%
# TESTING DATASET
# Hidden layer of the Neural Network 3
# Accuracy: 93.49999999999999%
# Text(0.5, 1.0, 'Position of players on football field')

# %% [markdown]
# ## Using NN with regulariation drop probablity =0.85

# %%
layer_dims=[20, 3, 1]
para,cost=NN_deep_layered(train_X,train_Y,layer_dims,num_iter=30000,learning_rate=0.3,ke_prob=0.7,print_cost=True,p_ty='He')
# Out:
# Number of Hidden layers in this Neural Network 3
# Units in each layer [20, 3, 1]
# At Iteration 0  Cost Function  0.8209964649585741
# At Iteration 1000  Cost Function  0.222170121528595
# At Iteration 2000  Cost Function  0.17839412693168336
# At Iteration 3000  Cost Function  0.17901071830508547
# At Iteration 4000  Cost Function  0.16837176480451957
# At Iteration 5000  Cost Function  0.1661107081908944
# At Iteration 6000  Cost Function  0.1640139513235005
# At Iteration 7000  Cost Function  0.16943277455427758
# At Iteration 8000  Cost Function  0.1662239570438663
# At Iteration 9000  Cost Function  0.17359610500884676
# At Iteration 10000  Cost Function  0.17104478519347874
# At Iteration 11000  Cost Function  0.16488726677682378
# At Iteration 12000  Cost Function  0.1694094023670612
# At Iteration 13000  Cost Function  0.16521548242429324
# At Iteration 14000  Cost Function  0.16394913081029597
# At Iteration 15000  Cost Function  0.17015449864853074
# At Iteration 16000  Cost Function  0.1669605260113168
# At Iteration 17000  Cost Function  0.16825980393101903
# At Iteration 18000  Cost Function  0.17260282560496065
# At Iteration 19000  Cost Function  0.16899840509365968
# At Iteration 20000  Cost Function  0.16657284894021526
# At Iteration 21000  Cost Function  0.16489753555959663
# At Iteration 22000  Cost Function  0.17091015369682697
# At Iteration 23000  Cost Function  0.16808739176801474
# At Iteration 24000  Cost Function  0.1628868709389306
# At Iteration 25000  Cost Function  0.1663735357348605
# At Iteration 26000  Cost Function  0.16359826432572233
# At Iteration 27000  Cost Function  0.17070948666029723
# At Iteration 28000  Cost Function  0.16946487469234825
# At Iteration 29000  Cost Function  0.16818017218092118

# %%
fig,ax=plt.subplots(figsize=(10,8))
ax.plot(cost)
plt.title('Learning curve (Not regularized)')
plt.xlabel('iteration')
plt.ylabel('cost')
plt.grid()

# %%
print('TRAINING DATASET')
p_train=predict(train_X,train_Y,para)
# Out:
# TRAINING DATASET
# Hidden layer of the Neural Network 3
# Accuracy: 90.52132701421802%

# %%
print('TESTING DATASET')
p_train=predict(test_X,test_Y,para)
# Out:
# TESTING DATASET
# Hidden layer of the Neural Network 3
# Accuracy: 90.99999999999999%

# %%
def pred(X, parameters, tol=0.5):
    m = X.shape[1]
    n_layers = len(parameters) // 2
    p = np.zeros((1, m))
    # Forward propagation
    probas, fw_caches = forward_propagation(X, parameters)
    # Activation function
    for i in range(0, probas.shape[1]):
        if probas[0, i] > tol:
            p[0, i] = 1
        else:
            p[0, i] = 0
    return p
X=train_X
Y=train_Y
x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
h = 0.01
# Generate a grid of points with distance h between them
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
# Predict the function value for the whole grid
Z = pred(np.c_[xx.ravel(), yy.ravel()].T,para)
Z = Z.reshape(xx.shape)
# Plot the contour and training examples
plt.figure(figsize=(12,6))
ax = plt.axes()
# Setting the background color
ax.set_facecolor("green")
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
plt.scatter(train_X[0, :], train_X[1, :], c=train_Y, s=40,cmap=mcolors.ListedColormap(["red", "blue"]));

plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.3)
plt.grid(axis='x',color = "white", linewidth = "0.5")
plt.title('Position of players on football field')
# Out:
# Text(0.5, 1.0, 'Position of players on football field')

# %% [markdown]
# ## The train and test error when used drop out with 0.7 are almost same No overfitting
